# %% [markdown]
# <a href="https://colab.research.google.com/github/FabriSC/strip/blob/main/strip.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/FabriSC/strip
# Out:
# fatal: destination path 'strip' already exists and is not an empty directory.

# %%
cd strip
# Out:
# /content/strip

# %%
# !chmod 777 *

# %%
# !sudo bash start.sh
# Out:
# Imported account 'fabriciosccorrea123@gmail.com'
# Switched to account 'fabriciosccorrea123@gmail.com'
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python3 is already the newest version (3.8.2-0ubuntu2).
# python3 set to manually installed.
# The following additional packages will be installed:
#   python-pip-whl python3-setuptools python3-wheel
# Suggested packages:
#   python-setuptools-doc
# The following NEW packages will be installed:
#   python-pip-whl python3-pip python3-setuptools python3-wheel
# 0 upgraded, 4 newly installed, 0 to remove and 22 not upgraded.
# Need to get 2,389 kB of archives.
# After this operation, 4,933 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python-pip-whl all 20.0.2-5ubuntu1.8 [1,805 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-setuptools all 45.2.0-1ubuntu0.1 [330 kB]
# ...
